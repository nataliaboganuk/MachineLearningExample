# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bogan\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\bogan\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (2.4.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (2.4.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\bogan\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bogan\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\bogan\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\bogan\appdata\roaming\python\python314\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\bogan\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bogan\appdata\roaming\python\python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\bogan\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data/uk_education_24_25.csv")

# %%
df.head()
# Out:
#    ReferenceNumber      SATS      GCSE    GCE_AS     GCE_A
# 0           924197  0.540542  0.779529  0.714935  0.686895
# 1           562958  0.748624  0.685546  0.857113  0.563323
# 2           381632  0.567128  0.753860  0.746305  0.669966
# 3           363028  0.732383  0.696386  0.816014  0.829543
# 4           176588  0.769215  0.721786  0.789809  0.820290

# %%
X = df.drop("GCE_A", axis=1)

# %%
y = df["GCE_A"]

# %%
pd.Series(y).value_counts()
# Out:
# GCE_A
# 1.000000    4
# 0.820290    1
# 0.779456    1
# 0.707723    1
# 0.831175    1
#            ..
# 0.616274    1
# 0.761062    1
# 0.769419    1
# 0.644470    1
# 0.829543    1
# Name: count, Length: 997, dtype: int64

# %%
#pd.Series(X).value_counts()

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\model_selection\_split.py:2945, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2941         CVClass = ShuffleSplit
#    2943     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
# -> 2945     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2947 xp, _, device = get_namespace_and_device(arrays[0])
#    2948 train, test = move_to(train, test, xp=xp, device=device)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\model_selection\_split.py:1928, in BaseShuffleSplit.split(self, X, y, groups)
#    1898 """Generate indices to split data into training and test set.
#    1899
#    1900 Parameters
#    (...)   1925 to an integer.
#    1926 """
#    1927 X, y, groups = indexable(X, y, groups)
# -> 1928 for train, test in self._iter_indices(X, y, groups):
#    1929     yield train, test
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\model_selection\_split.py:2346, in StratifiedShuffleSplit._iter_indices(self, X, y, groups)
#    2344 if np.min(class_counts) < 2:
#    2345     too_few_classes = classes[class_counts < 2].tolist()
# -> 2346     raise ValueError(
#    2347         "The least populated classes in y have only 1"
#    2348         " member, which is too few. The minimum"
#    2349         " number of groups for any class cannot"
#    2350         " be less than 2. Classes with too few"
#    2351         " members are: %s" % (too_few_classes)
#    2352     )
#    2354 if n_train < n_classes:
#    2355     raise ValueError(
#    2356         "The train_size = %d should be greater or "
#    2357         "equal to the number of classes = %d" % (n_train, n_classes)
#    2358     )
#
# ValueError: The least populated classes in y have only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2. Classes with too few members are: [0.3844480156773167, 0.3916110808154225, 0.3922124314911051, 0.4635630415647873, 0.4693119177145968, 0.4707307785242307, 0.4756788633111348, 0.4820947404369923, 0.4822888469441925, 0.4846719315321128, 0.4879717066189811, 0.4898884323887957, 0.4905588677011047, 0.4932567212210058, 0.4937593120544178, 0.4983713258615292, 0.4996003174591622, 0.5037769417317188, 0.5065606675485199, 0.5067090880075119, 0.5081471131250396, 0.509982967700531, 0.5112026656490078, 0.5118350073764898, 0.5156925187324106, 0.5176654672626152, 0.5212458611333, 0.5237264254018923, 0.5238768034909249, 0.5240046691665772, 0.5241479806292944, 0.5247387013114835, 0.5256029891445235, 0.5320789894881454, 0.5333505241763824, 0.5338773879737655, 0.5355590823473884, 0.5364768765890661, 0.5375957100192871, 0.5396826839508639, 0.5398720518444711, 0.5401695666469196, 0.5404449403365719, 0.5412108623725466, 0.5434044886585834, 0.5439083508337771, 0.5440925546736854, 0.544495899984205, 0.5452541670794528, 0.5467767819083218, 0.5478806474199701, 0.5480189106020412, 0.5494464659066389, 0.5526509574785442, 0.5529140794861612, 0.5534060747142705, 0.5545031599885684, 0.556521426613049, 0.557142411232012, 0.5604438512328508, 0.56138370009222, 0.5619358444953103, 0.5619793384354485, 0.5621619806322928, 0.5621872896176761, 0.5633233872133145, 0.5657398141660084, 0.5683003355464871, 0.5687509501007386, 0.5693809353360455, 0.5699321398780678, 0.571088567621068, 0.5711719502663535, 0.5725682929026829, 0.5732259641238634, 0.5738660469560081, 0.5742347022161325, 0.5755457281426738, 0.5766679956491445, 0.5775335858806925, 0.5777743434256819, 0.5795357022130943, 0.5820931599092845, 0.5826384458822809, 0.5827577140095845, 0.5832344812401257, 0.5836601937633655, 0.5869298033145927, 0.5878943736138235, 0.5886734829245635, 0.5887324147815733, 0.5888288774337677, 0.5888402212687076, 0.5889038246740576, 0.5902061774332976, 0.5904032830095043, 0.5914051680838462, 0.5918032054862048, 0.593437014454005, 0.594328071261409, 0.5949158234364972, 0.595083357267628, 0.5951601180539254, 0.595170646611558, 0.5972357211446716, 0.5973907666273476, 0.5977894415072662, 0.5977989165225159, 0.5978743593341145, 0.5979860932568826, 0.5980346928563965, 0.5980936274317652, 0.5983868326229235, 0.5995304390347819, 0.600662003577474, 0.6008442135854553, 0.6019118460442602, 0.6019667603232324, 0.6020318698155152, 0.6027079991712135, 0.6028432820188521, 0.6032806074692176, 0.6035207813372799, 0.6039692966824758, 0.6040304381672765, 0.6043690061362321, 0.6043953370836205, 0.6046034707149915, 0.6055381979966324, 0.6063150696167912, 0.6069835751720274, 0.6077829310926978, 0.608732565688822, 0.608915349934878, 0.6090646807111527, 0.6094303033183583, 0.6109628858449706, 0.6110791545528448, 0.6112835140262833, 0.6113691826771954, 0.6114447422555924, 0.6119177365026964, 0.6126737226707337, 0.6126763379169105, 0.6126776912648431, 0.6129981868884096, 0.6137435036518928, 0.613893364885735, 0.6141437986828259, 0.6142717126785314, 0.6160230233643218, 0.6162739841826089, 0.6163501069573599, 0.6166679237208421, 0.6171002283141921, 0.6175197748598615, 0.6179197993018397, 0.6187975729419832, 0.6188648025932466, 0.6193075786466286, 0.6204033563487376, 0.6204726814608336, 0.6209116460810694, 0.6210212493536795, 0.6213014293737724, 0.621568848713083, 0.621594479942414, 0.6216429080684202, 0.6221774833383088, 0.6223220339929063, 0.6228628045533044, 0.6230932286223825, 0.6231545982299683, 0.6240044201704698, 0.6242651686179159, 0.6244544128757503, 0.6250443660150995, 0.6250759390019901, 0.6251518877403661, 0.6254107480052316, 0.6254700909192182, 0.6256176100003841, 0.625843398254269, 0.6259892147666221, 0.6264832056008675, 0.6287875751373782, 0.6290221148088353, 0.6294312550955863, 0.6298319312171576, 0.6305229860105163, 0.6314221022400177, 0.632009633649556 ...

# %%
model = LogiticalRegression(max_iter=1000)

# %%
model.fit(XTrain,Ytrain)

# %%
Ypred = model.predict(XTest)

# %%
cm = confusionmatrix(Ytest, Y_pred)

# %%
cm

# %%
plt.figure(figsize=(6,4))

# %%
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")

# %%
plt.title("Confusion Matrix")

# %%
plt.xlabel("Predicted")

# %%
plt.ylabel("Actual")

# %%
plt.shot()

# %%
print(classificationreport(Ytest, Y_pred))
