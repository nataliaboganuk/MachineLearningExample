# %%
# Installs
# %pip install pandas
# %pip install scikit-learn
# %pip install seaborn
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score

# %%
# Load the Dataset
df = pd.read_csv("Data/synthetic_uk_attainment_10000_1.csv")
df.head()
# Out:
#     ref_id  SATS_score  GCSE_grade GCE_AS_grade GCE_A_grade GCE_A_Maths_grade
# 0  1006542         109           5            C           A                 C
# 1  1005075         104           6            A          A*                 B
# 2  1000951         110           7            B           C                 C
# 3  1000164         117           9            A           B                 B
# 4  1002633         103           7            A           B                 C

# %%
# ref_id               int
# SATS_score           int
# GCSE_grade           int (1–9)
# GCE_AS_grade         object (A, B, C, D, E, U)
# GCE_A_grade          object (A*, A, B, C, D, E, U)
# GCE_A_Maths_grade    object (A*, A, B, C, D, E, U)

# %%
grade_cols = ["GCE_AS_grade", "GCE_A_grade", "GCE_A_Maths_grade"]
df[grade_cols] = df[grade_cols].astype("object")

# %%
# Impact on the modelling pipeline
target_cols = [
    "SATS_score",
    "GCSE_grade",
    "GCE_AS_grade",
    "GCE_A_Maths_grade"
]

label_encoders = {}
Y_encoded = pd.DataFrame(index=df.index)

for col in target_cols:
    le = LabelEncoder()
    Y_encoded[col] = le.fit_transform(df[col])
    label_encoders[col] = le
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 13
#      10 Y_encoded = pd.DataFrame(index=df.index)
#      12 for col in target_cols:
# ---> 13     le = LabelEncoder()
#      14     Y_encoded[col] = le.fit_transform(df[col])
#      15     label_encoders[col] = le
#
# NameError: name 'LabelEncoder' is not defined

# %%
#Updated “schema validation” section
import pandas as pd

df = pd.read_csv("synthetic_uk_attainment_10000_1.csv")

# Enforce expected types
df["ref_id"] = df["ref_id"].astype(int)
df["SATS_score"] = df["SATS_score"].astype(int)
df["GCSE_grade"] = df["GCSE_grade"].astype(int)

grade_cols = ["GCE_AS_grade", "GCE_A_grade", "GCE_A_Maths_grade"]
df[grade_cols] = df[grade_cols].astype("object")

df.info()
df.head()
