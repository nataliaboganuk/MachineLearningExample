# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("uk_education_24_25.csv")

# %%
df.head()
# Out:
#    ReferenceNumber      SATS      GCSE    GCE_AS     GCE_A
# 0           924197  0.540542  0.779529  0.714935  0.686895
# 1           562958  0.748624  0.685546  0.857113  0.563323
# 2           381632  0.567128  0.753860  0.746305  0.669966
# 3           363028  0.732383  0.696386  0.816014  0.829543
# 4           176588  0.769215  0.721786  0.789809  0.820290

# %%
X = df.drop("GCE_A", axis=1)

# %%
Y = df["GCE_A"]

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, testsize=0.20, randomstate=42,stratify=Y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, testsize=0.20, randomstate=42,stratify=Y)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\inspect.py:3234, in Signature.bind(self, *args, **kwargs)
#    3229 def bind(self, /, *args, **kwargs):
#    3230     """Get a BoundArguments object, that maps the passed `args`
# ...

# %%
model = LogiticalRegression(max_iter=1000)

# %%
model.fit(XTrain,Ytrain)

# %%
Ypred = model.predict(XTest)

# %%
cm = confusionmatrix(Ytest, Y_pred)

# %%
cm

# %%
plt.figure(figsize=(6,4))

# %%
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")

# %%
plt.title("Confusion Matrix")

# %%
plt.xlabel("Predicted")

# %%
plt.ylabel("Actual")

# %%
plt.shot()

# %%
print(classificationreport(Ytest, Y_pred))
